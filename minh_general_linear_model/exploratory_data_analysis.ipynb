# %% [markdown]
# # Break Through Tech - Allstate Team 1b
# ## Author: Minh Le
# ---
#
# This file is used to perform exploratory data analysis from the dataset given by the client (Allstate). The end goal will be explore all the important features as well as understand the data more before working on the modeling part of the project.
#
# ### 1. Import Libraries and Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../data/claims_data.csv')
df.head()
# Out:
#    id cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8 cat9  ...     cont6     cont7  \
# 0   1    A    B    A    B    A    A    A    A    B  ...  0.718367  0.335060
# 1   2    A    B    A    A    A    A    A    A    B  ...  0.438917  0.436585
# 2   5    A    B    A    A    B    A    A    A    B  ...  0.289648  0.315545
# 3  10    B    B    A    B    A    A    A    A    B  ...  0.440945  0.391128
# 4  11    A    B    A    B    A    A    A    A    B  ...  0.178193  0.247408
#
#      cont8    cont9   cont10    cont11    cont12    cont13    cont14     loss
# 0  0.30260  0.67135  0.83510  0.569745  0.594646  0.822493  0.714843  2213.18
# 1  0.60087  0.35127  0.43919  0.338312  0.366307  0.611431  0.304496  1283.60
# 2  0.27320  0.26076  0.32446  0.381398  0.373424  0.195709  0.774425  3005.09
# 3  0.31796  0.32128  0.44467  0.327915  0.321570  0.605077  0.602642   939.85
# 4  0.24564  0.22089  0.21230  0.204687  0.202213  0.246011  0.432606  2763.85
#
# [5 rows x 132 columns]

# %% [markdown]
# ### 2. Quick Data Overview

# %%
print("Shape:", df.shape)
print("-----------------------")
print("Data types:\n", df.dtypes.value_counts())
print("-----------------------")
print("Missing values:", df.isnull().sum().sort_values(ascending=False).sum())
# Out:
# Shape: (188318, 132)
# -----------------------
# Data types:
#  object     116
# float64     15
# int64        1
# Name: count, dtype: int64
# -----------------------
# Missing values: 0

# %% [markdown]
# Note:
# - There are 116 categorical variables and 15 continuous variables
# - There is no missing value

# %%
# Separate columns by cat and con
id_col = "id"
target_col = "loss"
categorical_cols = [c for c in df.columns if c.startswith("cat")]
continuous_cols = [c for c in df.columns if c.startswith("cont")]

# %% [markdown]
# ### 3. Target Variable
#
# The target variable in the data is `loss`, which is what we're trying to predict.

# %%
print("Target Summary:\n", df[target_col].describe())

plt.figure(figsize=(8,5))
sns.histplot(df[target_col], bins=50, kde=True)
plt.title("Distribution of Loss (Target)")
plt.show()
# Out:
# Target Summary:
#  count    188318.000000
# mean       3037.337686
# std        2904.086186
# min           0.670000
# 25%        1204.460000
# 50%        2115.570000
# 75%        3864.045000
# max      121012.250000
# Name: loss, dtype: float64

# %% [markdown]
# ### 4. Continuous Variables

# %%
# Correlation matrix
plt.figure(figsize=(12,8))
corr = df[continuous_cols + [target_col]].corr()
sns.heatmap(corr, annot=False, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap (Continuous Features + Target)")
plt.show()

# %%
# Compute correlation matrix
corr_matrix = df[continuous_cols + [target_col]].corr()

# Set a threshold for "high correlation"
threshold = 0.6  

# Extract pairs with high correlation (absolute value)
high_corr = (
    corr_matrix.unstack()
    .reset_index()
    .rename(columns={"level_0":"Feature1", "level_1":"Feature2", 0:"Correlation"})
)

# Remove duplicates and self-correlations
high_corr = high_corr[
    (high_corr["Feature1"] < high_corr["Feature2"]) & 
    (abs(high_corr["Correlation"]) >= threshold)
].sort_values(by="Correlation", ascending=False)

high_corr
# Out:
#     Feature1 Feature2  Correlation
# 161   cont11   cont12     0.994384
# 8      cont1    cont9     0.929912
# 140   cont10    cont6     0.883351
# 185   cont13    cont6     0.815091
# 9      cont1   cont10     0.808551
# 83     cont6    cont9     0.797544
# 143   cont10    cont9     0.785697
# 170   cont12    cont6     0.785144
# 155   cont11    cont6     0.773745
# 5      cont1    cont6     0.758315
# 156   cont11    cont7     0.747108
# 171   cont12    cont7     0.742712
# 146   cont10   cont12     0.713812
# 147   cont10   cont13     0.707876
# 145   cont10   cont11     0.702896
# 81     cont6    cont7     0.658918
# 188   cont13    cont9     0.642028
# 173   cont12    cont9     0.626656
# 11     cont1   cont12     0.614225
# 158   cont11    cont9     0.608000

# %% [markdown]
# ### 5. Categorical Variables
#
# I will explore the first 17 categorical variables

# %%
features = [f'cat{i}' for i in range(1, 18)]
features.append('loss')
features.append('id')

df_shortened = df[features]

# %%
for col in features:
    print(f"Number of unique values in {col} columns: {df[col].nunique()}")
# Out:
# Number of unique values in cat1 columns: 2
# Number of unique values in cat2 columns: 2
# Number of unique values in cat3 columns: 2
# Number of unique values in cat4 columns: 2
# Number of unique values in cat5 columns: 2
# Number of unique values in cat6 columns: 2
# Number of unique values in cat7 columns: 2
# Number of unique values in cat8 columns: 2
# Number of unique values in cat9 columns: 2
# Number of unique values in cat10 columns: 2
# Number of unique values in cat11 columns: 2
# Number of unique values in cat12 columns: 2
# Number of unique values in cat13 columns: 2
# Number of unique values in cat14 columns: 2
# Number of unique values in cat15 columns: 2
# Number of unique values in cat16 columns: 2
# Number of unique values in cat17 columns: 2
# Number of unique values in loss columns: 158223
# Number of unique values in id columns: 188318

# %%
for col in features:
    print(f"Number of unique values in {col} columns: {df[col].unique()}")
# Out:
# Number of unique values in cat1 columns: ['A' 'B']
# Number of unique values in cat2 columns: ['B' 'A']
# Number of unique values in cat3 columns: ['A' 'B']
# Number of unique values in cat4 columns: ['B' 'A']
# Number of unique values in cat5 columns: ['A' 'B']
# Number of unique values in cat6 columns: ['A' 'B']
# Number of unique values in cat7 columns: ['A' 'B']
# Number of unique values in cat8 columns: ['A' 'B']
# Number of unique values in cat9 columns: ['B' 'A']
# Number of unique values in cat10 columns: ['A' 'B']
# Number of unique values in cat11 columns: ['B' 'A']
# Number of unique values in cat12 columns: ['A' 'B']
# Number of unique values in cat13 columns: ['A' 'B']
# Number of unique values in cat14 columns: ['A' 'B']
# Number of unique values in cat15 columns: ['A' 'B']
# Number of unique values in cat16 columns: ['A' 'B']
# Number of unique values in cat17 columns: ['A' 'B']
# Number of unique values in loss columns: [2213.18 1283.6  3005.09 ... 1108.34 5762.64 4751.72]
# Number of unique values in id columns: [     1      2      5 ... 587630 587632 587633]

# %%
# list of categorical columns
cat_cols = [f'cat{i}' for i in range(1, 18)]

# define subplot grid size
ncols = 4
nrows = (len(cat_cols) + ncols - 1) // ncols

plt.figure(figsize=(20, 20))

for idx, col in enumerate(cat_cols, 1):
    plt.subplot(nrows, ncols, idx)
    sns.boxplot(x=col, y='loss', data=df)
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.yscale('log')
    plt.ylabel("Loss")

plt.tight_layout()
plt.show()

# %% [markdown]
# Note:
# - `cat3`, `cat7`, `cat10`, `cat11`, `cat12`, `cat16`, `cat17`: Different in the median/spread
# - `cat1`, `cat2`, `cat6`, `cat9`, `cat13`, `cat14`: Slight different
# - `cat4`, `cat5`, `cat8`, `cat15`: No different
